# %%
import pandas as pd 
import numpy as  np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"Downloads/dev.csv")
df.head()
# Out:
#   ISO3               Country Human Development Groups UNDP Developing Regions  \
# 0  AFG           Afghanistan                      Low                      SA
# 1  AGO                Angola                   Medium                     SSA
# 2  ALB               Albania                     High                     ECA
# 3  AND               Andorra                Very High                     NaN
# 4  ARE  United Arab Emirates                Very High                      AS
#
#    HDI Rank (2021)  Human Development Index (1990)  \
# 0            180.0                           0.273
# 1            148.0                             NaN
# 2             67.0                           0.647
# 3             40.0                             NaN
# 4             26.0                           0.728
#
#    Human Development Index (1991)  Human Development Index (1992)  \
# 0                           0.279                           0.287
# ...

# %%
#droping the columns we dont need 
columns=df.columns.values.tolist()
for i in df.columns.values:
    year = list(i)
    try:
        year=int(''.join(year[len(year)-5:len(year)-1]))
        if year<2021 and year>1990:
            df=df.drop(i,axis=1)
    except Exception as e:
        pass
df=df.drop(['ISO3','Human Development Groups','UNDP Developing Regions','HDI Rank (2021)'],axis=1)
df2=df.query("Country == 'Algeria' | Country == 'Egypt' | Country == 'Morocco' | Country == 'Tunisia' | Country == 'Canada'")
df2
# Out:
#      Country  Human Development Index (1990)  Human Development Index (2021)  \
# 29    Canada                           0.860                           0.936
# 49   Algeria                           0.591                           0.745
# 51     Egypt                           0.572                           0.731
# 107  Morocco                           0.447                           0.683
# 177  Tunisia                           0.576                           0.731
#
#      Life Expectancy at Birth (1990)  Life Expectancy at Birth (2021)  \
# 29                           77.4308                          82.6565
# 49                           67.4160                          76.3767
# 51                           64.1459                          70.2207
# 107                          62.4478                          74.0419
# 177                          70.1103                          73.7719
#
#      Expected Years of Schooling (1990)  Expected Years of Schooling (2021)  \
# ...

# %%
df2.isnull()
# Out:
#      Country  Human Development Index (1990)  Human Development Index (2021)  \
# 29     False                           False                           False
# 49     False                           False                           False
# 51     False                           False                           False
# 107    False                           False                           False
# 177    False                           False                           False
#
#      Life Expectancy at Birth (1990)  Life Expectancy at Birth (2021)  \
# 29                             False                            False
# 49                             False                            False
# 51                             False                            False
# 107                            False                            False
# 177                            False                            False
#
#      Expected Years of Schooling (1990)  Expected Years of Schooling (2021)  \
# ...

# %%
### Human Development Index (1990)
columns=df2.columns.values.tolist()
i=1
while(i<len(columns)-1):
    plt.figure(figsize=(8,4))
    sns.barplot(x = df2['Country'], y = df2[columns[i]], data = df2)
    sns.barplot(x = df2['Country'], y = df2[columns[i+1]], data = df2, hue = df2[columns[i]], palette=["#c4f8ef","#ffbdd6","#bde0ff"])
    plt.legend([],[], frameon=False)
    print(columns[i]+" and (2020)")
    plt.show()
    i=i+2
# Out:
# Human Development Index (1990) and (2020)
# Life Expectancy at Birth (1990) and (2020)
# Expected Years of Schooling (1990) and (2020)
# Mean Years of Schooling (1990) and (2020)
# Gross National Income Per Capita (1990) and (2020)
# GDI Group (2021) and (2020)
# Gender Development Index (2021) and (2020)
# HDI female (2021) and (2020)
# Life Expectancy at Birth, female (2021) and (2020)
# Expected Years of Schooling, female (2021) and (2020)
# Mean Years of Schooling, female (2021) and (2020)
# Gross National Income Per Capita, female (2021) and (2020)
# HDI male (2021) and (2020)
# Life Expectancy at Birth, male (2021) and (2020)
# Expected Years of Schooling, male (2021) and (2020)
# Mean Years of Schooling, male (2021) and (2020)
# Gross National Income Per Capita, male (2021) and (2020)
# Coefficient of human inequality (2021) and (2020)
# Inequality in life expectancy (2021) and (2020)
# Inequality in income (2021) and (2020)
# Gender Inequality Index (1990) and (2020)
# ...

# %%
gg
